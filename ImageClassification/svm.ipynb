# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn import svm
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split 

import pickle

# %%
X_train = pickle.load( open("x_train.p", "rb"))
Y_train = pickle.load( open("y_train.p", "rb"))

# %%
data,Label = shuffle(X_train,Y_train, random_state=2)
 
X_train.reshape(2000,22500)

train_data = [data, Label]


print(train_data[0].shape)
print(train_data[1].shape)
# Out:
# (2000, 22500)
# (2000, 1)

# %%
clf = svm.SVC(gamma=0.0001, C=100)
x,y = train_data[0], train_data[1]

# %%
clf.fit(x,y)
# Out:
# /home/paperspace/anaconda3/envs/interview/lib/python3.7/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.0001, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
S = pickle.dump(clf,open("svm_cat.p","wb"))

# %%
X_test = pickle.load( open("x_test.p", "rb"))
Y_test = pickle.load( open("y_test.p", "rb"))

# %%
target_data,target_label = shuffle(X_test,Y_test, random_state=2)
X_test.reshape(184,22500)

test_data = [target_data, target_label]


print(test_data[0].shape)
print(test_data[1].shape)
# Out:
# (184, 22500)
# (184, 1)

# %%
clf2 = pickle.load(open("svm_cat.p","rb"))

# %%
prediction = np.array([])
prediction = clf2.predict(target_data[0:10])
# Out:
# [7. 0. 0. 1. 8. 4. 1. 2. 2. 0.]

# %%
df = pd.read_csv('Product-Brand.txt', header=None)
df = df[7:]
print(df)
# Out:
#               0  1
# 7         shoes  0
# 8      lipstick  1
# 9       handbag  2
# 10  nail polish  3
# 11     necklace  4
# 12      watches  5
# 13         ring  6
# 14     bracelet  7
# 15        boots  8
# 16     earrings  9

# %%
dictionary = df.to_dict(orient='index')
print(dictionary)
# Out:
# {7: {0: 'shoes', 1: 0}, 8: {0: 'lipstick', 1: 1}, 9: {0: 'handbag', 1: 2}, 10: {0: 'nail polish', 1: 3}, 11: {0: 'necklace', 1: 4}, 12: {0: 'watches', 1: 5}, 13: {0: 'ring', 1: 6}, 14: {0: 'bracelet', 1: 7}, 15: {0: 'boots', 1: 8}, 16: {0: 'earrings', 1: 9}}

# %%
   for i in range(0,10): 
        target = target_data[i:i+1].reshape(150,150)
        plt.imshow(target)
        plt.show()
